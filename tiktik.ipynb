# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
import string
import re
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")

data = pd.read_csv("tiktok.csv")
data.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MuhammadNurAlim\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                             reviewId        userName  \
# 0  gp:AOqpTOHRz-11c0apHLSKHHp52FxUXsQS9Z88wP3sWc5...    MR LOL GAMER
# 1  gp:AOqpTOF6mFDEkIypmyT3shDLjPHg8zB3kdns2W36ahp...     Dino Kljako
# 2  gp:AOqpTOGtqU4sb8vuVo3-eB7kIXWoBn-0YCUZ1SnPRKS...  Olivia Harding
# 3  gp:AOqpTOFHDm-Qa5R6jCpOGTFT2qr1_PKbCTbBNPahCEn...         Keli We
# 4  gp:AOqpTOFB6Ndao8IHRpOJRmbSknwMGxHcwYzux93YyXI...    Mavis Kotoka
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a/AATXAJ...
#
# ...

# %%
data = data[["content", "score"]]
print(data.head())
# Out:
#                                              content  score
# 0                                               Good      5
# 1  Awesome app! Too many people on it where it's ...      5
# 2                                            Not bad      5
# 3                                         It is good      2
# 4                               Very interesting app      5

# %%
data.isnull().sum()
# Out:
# content    4
# score      0
# dtype: int64

# %%
data = data.dropna()

# %%
stopword = set(stopwords.words('english'))
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\s+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text = " ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text = " ".join(text)
    return text
data["content"] = data["content"].apply(clean)

# %%
ratings = data["score"].value_counts()
numbers = ratings.index
quantity = ratings.values
import plotly.express as px
figure = px.pie(data, values = quantity, names = numbers, hole = .5)

figure.show()

# %%
# text = "".join(str(i) for i in data.content)
#other
text = "".join(i for i in map(str, data.content))
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords = stopwords, background_color="white").generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud ,interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
data["positive"] = [sentiments.polarity_scores(i)["pos"] for i in map(str,data["content"])]
data["negative"] = [sentiments.polarity_scores(i)["neg"] for i in map(str,data["content"])]
data["neutral"] = [sentiments.polarity_scores(i)["neu"] for i in map(str,data["content"])]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\MuhammadNurAlim\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
data = data[["content", "positive", "negative", "neutral"]]
data.head()
# Out:
#                                              content  positive  negative  \
# 0                                               good     1.000       0.0
# 1  aweom app! mani peopl it eaier fb. girl aweom ...     0.246       0.0
# 2                                                bad     0.000       1.0
# 3                                               good     1.000       0.0
# 4                                        interet app     0.000       0.0
#
#    neutral
# 0    0.000
# 1    0.754
# 2    0.000
# 3    0.000
# 4    1.000

# %%
positive = ''.join([str(i) for i in data['content'][data['positive']>data["negative"]]])
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(positive)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
negative = ''.join([str(i) for i in data['content'][data['negative'] > data["positive"]]])
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(negative)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
